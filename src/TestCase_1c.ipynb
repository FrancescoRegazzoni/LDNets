# %% [markdown]
# # Learning the dynamics of PDEs with LDNet (Test Case 1c)

# %% [markdown]
# This notebook contains a tutorial with an example of usage of an LDNet to learn the dynamics underlying the following Diffusion-Reaction equation (Test case 1c, Section 3.1.4 of the Supplementary Information):
# $$
# \begin{cases}
# \frac{\partial z(x,t)}{\partial t} - \mu_1 \frac{\partial^2 z(x,t)}{\partial x^2} + \mu_3 z(x,t) = A(t) \cos(2 \pi F(t) x − P(t)), & x \in (-1,1), t\in (0,T], \\
# z(-1,t) = z(1,t) & t\in (0,T], \\
# z(x,0)= 0 & x \in (-1,1).
# \end{cases}
# $$
# with parameters $\mu_1 = 0.05$ and $\mu_3 = 0.02$. The LDNet is trained in order to predict the space-time dynamics of $z(x,t)$ for a generic input $\mathbf{u}(t) = (A(t), F(t), P(t))$.

# %%
# import modules
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# We configure TensorFlow to work in double precision 
tf.keras.backend.set_floatx('float64')

import utils
import optimization

# %% [markdown]
# ### Problem setting
#
# We define the name of the variables of the problem at hand.

# %%
problem = {
    'space': {
        'dimension' : 1
    },
    'input_parameters': [],
    'input_signals': [
        { 'name': 'amplitude' },
        { 'name': 'phase' },
        { 'name': 'frequency' }
    ],
    'output_fields': [
        { 'name': 'z' }
    ]
}

# %% [markdown]
# We define, for each variable, a lower and an upper bound to be used to normalize the data.

# %%
normalization = {
    'space': { 'min' : [-1], 'max' : [+1]},
    'time': { 'time_constant' : 8 },
    'input_signals': {
        'amplitude': { 'min':   0, 'max': 2},
        'phase'    : { 'min':  -4, 'max': 4 },
        'frequency': { 'min':   0.25, 'max': 1 },
    },
    'output_fields': {
        'z': { 'min': -4, 'max': +4 }
    }
}

# %% [markdown]
# We define the time step size and the number of latent variables used by the LDNet.

# %%
dt = 5e-2
num_latent_states = 4

# %% [markdown]
# ### Datasets
#
# We load training, validation and testing data. Here, training, validation and test sets comprise $n_{\mathrm{samples}} = 100$ samples each.
# We resample data points on a regular grid with $n_{\mathrm{times}} = 101$ time instants and $n_{\mathrm{points}} = 100$ space points.
# By following the notation of the paper, we denote by $d = 1$ the spatial dimension, by $d_{\mathbf{u}} = 3$ the number of input parameters and by $d_{\mathbf{y}} = 1$ the number of output fields.
#
# Each dataset is stored as a Python dictionary, with the following fields (shape is indicated in square brackets):
# - `times` $[n_{\mathrm{times}}]$: time instants;
# - `points` $[n_{\mathrm{points}}, d]$: space points;
# - `points_full` $[n_{\mathrm{samples}}, n_{\mathrm{times}}, n_{\mathrm{points}}, d]$: space points repeated for each sample and time instant;
# - `inp_signals` $[n_{\mathrm{samples}}, n_{\mathrm{times}}, d_{\mathbf{u}}]$: input signals for each sample and time instant;
# - `out_fields` $[n_{\mathrm{samples}}, n_{\mathrm{times}}, n_{\mathrm{points}}, d_{\mathbf{y}}]$: output fields for each sample, time instant and space point.

# %%
data_set_path = '../data/ADR/data_1c_fmax1.0.npy'
samples_train = np.arange(  0, 100)
samples_valid = np.arange(100, 200)
samples_tests = np.arange(200, 300)

dataset = np.load(data_set_path, allow_pickle = True)[()]
dataset_train = utils.ADR_create_dataset(dataset, samples_train)
dataset_valid = utils.ADR_create_dataset(dataset, samples_valid) 
dataset_tests = utils.ADR_create_dataset(dataset, samples_tests) 

# We re-sample the time transients with timestep dt and we rescale each variable between -1 and 1.
utils.process_dataset(dataset_train, problem, normalization, dt = dt)
utils.process_dataset(dataset_valid, problem, normalization, dt = dt)
utils.process_dataset(dataset_tests, problem, normalization, dt = dt)

# %% [markdown]
# ### Architecture
#
# We create two fully-connected neural networks of which the LDNet is made up:
# - the dynamics network $\mathcal{NN}_{\mathrm{dyn}}$, with two hidden layers of 16 neurons each;
# - the reconstruction network $\mathcal{NN}_{\mathrm{rec}}$, with two hidden layers of 8 neurons each.

# %%
# For reproducibility (delete if you want to test other random initializations)
np.random.seed(0)
tf.random.set_seed(0)

# dynamics network
input_shape = (num_latent_states + len(problem['input_parameters']) + len(problem['input_signals']),)
NNdyn = tf.keras.Sequential([
            tf.keras.layers.Dense(16, activation = tf.nn.tanh, input_shape = input_shape),
            tf.keras.layers.Dense(16, activation = tf.nn.tanh),
            tf.keras.layers.Dense(num_latent_states)
        ])

# summary
NNdyn.summary()

# visualization
tf.keras.utils.plot_model(NNdyn, show_shapes=True, show_layer_names=False, show_layer_activations=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                128
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 468
# Trainable params: 468
# Non-trainable params: 0
# _________________________________________________________________

# %%
# reconstruction network
input_shape = (None, None, num_latent_states + problem['space']['dimension'])
NNrec = tf.keras.Sequential([
            tf.keras.layers.Dense(8, activation = tf.nn.tanh, input_shape = input_shape),
            tf.keras.layers.Dense(8, activation = tf.nn.tanh),
            tf.keras.layers.Dense(len(problem['output_fields']))
        ])

# summary
NNrec.summary()

# visualization
tf.keras.utils.plot_model(NNrec, show_shapes=True, show_layer_names=False, show_layer_activations=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, None, None, 8)     48
#
#  dense_4 (Dense)             (None, None, None, 8)     72
#
#  dense_5 (Dense)             (None, None, None, 1)     9
#
# =================================================================
# Total params: 129
# Trainable params: 129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The LDNet action is defined through the following two functions:
# - `evolve_dynamics` computes the evolution of the latent states;
# - `reconstruct_output` reconstructs the output field from the latent states evolution.

# %%
def evolve_dynamics(dataset):
    # intial condition
    state = tf.zeros((dataset['num_samples'], num_latent_states), dtype=tf.float64)
    state_history = tf.TensorArray(tf.float64, size = dataset['num_times'])
    state_history = state_history.write(0, state)
    dt_ref = normalization['time']['time_constant']
    
    # time integration
    for i in tf.range(dataset['num_times'] - 1):
        state = state + dt/dt_ref * NNdyn(tf.concat([state, dataset['inp_signals'][:,i,:]], axis = -1))
        state_history = state_history.write(i + 1, state)

    return tf.transpose(state_history.stack(), perm=(1,0,2))

def reconstruct_output(dataset, states):    
    states_expanded = tf.broadcast_to(tf.expand_dims(states, axis = 2), 
        [dataset['num_samples'], dataset['num_times'], dataset['num_points'], num_latent_states])
    return NNrec(tf.concat([states_expanded, dataset['points_full']], axis = 3))

def LDNet(dataset):
    states = evolve_dynamics(dataset)
    return reconstruct_output(dataset, states)

# %% [markdown]
# ### Loss function
#
# We define the loss function as the MSE (mean square error) over the whole dataset plus a Tikhonov regularization on the NNs' weights.

# %%
def MSE(dataset):
    out_fields = LDNet(dataset)
    error = out_fields - dataset['out_fields']
    return tf.reduce_mean(tf.square(error))

def weights_reg(NN):
    return sum([tf.reduce_mean(tf.square(lay.kernel)) for lay in NN.layers])/len(NN.layers)

alpha_reg = 2.7e-4
def loss(): return MSE(dataset_train) + alpha_reg * (weights_reg(NNdyn) + weights_reg(NNrec))
def MSE_valid(): return MSE(dataset_valid)

# %% [markdown]
# ### LDNet training
#
# We train the LDNet with $100$ iterations based on the Adam optimizer, followed by $1800$ iterations based on the BFGS optimizer.
# Notice that the trainable variables of the LDNet are given as the union of the trainable variables of $\mathcal{NN}_{\mathrm{dyn}}$ and $\mathcal{NN}_{\mathrm{rec}}$.

# %%
trainable_variables = NNdyn.variables + NNrec.variables
opt = optimization.OptimizationProblem(trainable_variables, loss, MSE_valid)

num_epochs_Adam = 200
num_epochs_BFGS = 1800

print('training (Adam)...')
opt.optimize_keras(num_epochs_Adam, tf.keras.optimizers.Adam(learning_rate=1e-2))
print('training (BFGS)...')
opt.optimize_BFGS(num_epochs_BFGS)
# Out:
# Tracing functions with autograph...
# Tracing completed.
# epoch    0   -   training loss: 2.695e-01   -   validation loss 2.822e-01
# training (Adam)...
# epoch   10   -   training loss: 6.382e-02   -   validation loss 6.190e-02
# epoch   20   -   training loss: 4.540e-02   -   validation loss 4.679e-02
# epoch   30   -   training loss: 4.254e-02   -   validation loss 4.433e-02
# epoch   40   -   training loss: 4.172e-02   -   validation loss 4.303e-02
# epoch   50   -   training loss: 4.052e-02   -   validation loss 4.163e-02
# epoch   60   -   training loss: 3.997e-02   -   validation loss 4.116e-02
# epoch   70   -   training loss: 3.929e-02   -   validation loss 4.071e-02
# epoch   80   -   training loss: 3.879e-02   -   validation loss 4.036e-02
# epoch   90   -   training loss: 3.835e-02   -   validation loss 3.997e-02
# epoch  100   -   training loss: 3.787e-02   -   validation loss 3.946e-02
# epoch  110   -   training loss: 3.727e-02   -   validation loss 3.888e-02
# epoch  120   -   training loss: 3.647e-02   -   validation loss 3.807e-02
# epoch  130   -   training loss: 3.529e-02   -   validation loss 3.688e-02
# epoch  140   -   training loss: 3.341e-02   -   validation loss 3.507e-02
# epoch  150   -   training loss: 3.028e-02   -   validation loss 3.221e-02
# epoch  160   -   training loss: 2.627e-02   -   validation loss 2.835e-02
# epoch  170   -   training loss: 2.280e-02   -   validation loss 2.490e-02
# epoch  180   -   training loss: 2.027e-02   -   validation loss 2.237e-02
# epoch  190   -   training loss: 1.814e-02   -   validation loss 2.014e-02
# epoch  200   -   training loss: 1.633e-02   -   validation loss 1.821e-02
# training (BFGS)...
# epoch  210   -   training loss: 1.258e-02   -   validation loss 1.445e-02
# epoch  220   -   training loss: 1.141e-02   -   validation loss 1.352e-02
# epoch  230   -   training loss: 1.025e-02   -   validation loss 1.226e-02
# epoch  240   -   training loss: 8.870e-03   -   validation loss 1.062e-02
# epoch  250   -   training loss: 8.009e-03   -   validation loss 9.266e-03
# epoch  260   -   training loss: 7.358e-03   -   validation loss 8.215e-03
# epoch  270   -   training loss: 6.455e-03   -   validation loss 7.171e-03
# epoch  280   -   training loss: 5.957e-03   -   validation loss 6.554e-03
# epoch  290   -   training loss: 5.398e-03   -   validation loss 5.782e-03
# epoch  300   -   training loss: 4.902e-03   -   validation loss 5.303e-03
# epoch  310   -   training loss: 4.449e-03   -   validation loss 4.944e-03
# epoch  320   -   training loss: 4.097e-03   -   validation loss 4.699e-03
# epoch  330   -   training loss: 3.864e-03   -   validation loss 4.413e-03
# epoch  340   -   training loss: 3.686e-03   -   validation loss 4.215e-03
# epoch  350   -   training loss: 3.494e-03   -   validation loss 3.994e-03
# epoch  360   -   training loss: 3.315e-03   -   validation loss 3.656e-03
# epoch  370   -   training loss: 3.156e-03   -   validation loss 3.509e-03
# epoch  380   -   training loss: 3.009e-03   -   validation loss 3.408e-03
# epoch  390   -   training loss: 2.865e-03   -   validation loss 3.243e-03
# epoch  400   -   training loss: 2.778e-03   -   validation loss 3.210e-03
# epoch  410   -   training loss: 2.694e-03   -   validation loss 3.101e-03
# epoch  420   -   training loss: 2.626e-03   -   validation loss 3.017e-03
# epoch  430   -   training loss: 2.544e-03   -   validation loss 3.023e-03
# epoch  440   -   training loss: 2.478e-03   -   validation loss 2.991e-03
# epoch  450   -   training loss: 2.412e-03   -   validation loss 2.762e-03
# epoch  460   -   training loss: 2.367e-03   -   validation loss 2.696e-03
# epoch  470   -   training loss: 2.296e-03   -   validation loss 2.752e-03
# epoch  480   -   training loss: 2.227e-03   -   validation loss 2.586e-03
# epoch  490   -   training loss: 2.181e-03   -   validation loss 2.573e-03
# epoch  500   -   training loss: 2.128e-03   -   validation loss 2.544e-03
# epoch  510   -   training loss: 2.074e-03   -   validation loss 2.444e-03
# epoch  520   -   training loss: 2.016e-03   -   validation loss 2.270e-03
# epoch  530   -   training loss: 1.978e-03   -   validation loss 2.185e-03
# epoch  540   -   training loss: 1.951e-03   -   validation loss 2.136e-03
# epoch  550   -   training loss: 1.904e-03   -   validation loss 2.076e-03
# epoch  560   -   training loss: 1.880e-03   -   validation loss 2.012e-03
# epoch  570   -   training loss: 1.853e-03   -   validation loss 2.039e-03
# epoch  580   -   training loss: 1.797e-03   -   validation loss 1.979e-03
# epoch  590   -   training loss: 1.770e-03   -   validation loss 1.946e-03
# epoch  600   -   training loss: 1.739e-03   -   validation loss 1.883e-03
# epoch  610   -   training loss: 1.693e-03   -   validation loss 1.742e-03
# epoch  620   -   training loss: 1.634e-03   -   validation loss 1.665e-03
# epoch  630   -   training loss: 1.609e-03   -   validation loss 1.622e-03
# epoch  640   -   training loss: 1.569e-03   -   validation loss 1.583e-03
# epoch  650   -   training loss: 1.543e-03   -   validation loss 1.549e-03
# epoch  660   -   training loss: 1.515e-03   -   validation loss 1.497e-03
# epoch  670   -   training loss: 1.480e-03   -   validation loss 1.415e-03
# epoch  680   -   training loss: 1.453e-03   -   validation loss 1.442e-03
# epoch  690   -   training loss: 1.430e-03   -   validation loss 1.412e-03
# epoch  700   -   training loss: 1.415e-03   -   validation loss 1.410e-03
# epoch  710   -   training loss: 1.397e-03   -   validation loss 1.356e-03
# epoch  720   -   training loss: 1.385e-03   -   validation loss 1.350e-03
# epoch  730   -   training loss: 1.367e-03   -   validation loss 1.322e-03
# epoch  740   -   training loss: 1.358e-03   -   validation loss 1.318e-03
# epoch  750   -   training loss: 1.343e-03   -   validation loss 1.313e-03
# epoch  760   -   training loss: 1.322e-03   -   validation loss 1.281e-03
# epoch  770   -   training loss: 1.313e-03   -   validation loss 1.274e-03
# epoch  780   -   training loss: 1.299e-03   -   validation loss 1.276e-03
# epoch  790   -   training loss: 1.292e-03   -   validation loss 1.268e-03
# epoch  800   -   training loss: 1.281e-03   -   validation loss 1.261e-03
# epoch  810   -   training loss: 1.269e-03   -   validation loss 1.261e-03
# epoch  820   -   training loss: 1.258e-03   -   validation loss 1.251e-03
# epoch  830   -   training loss: 1.244e-03   -   validation loss 1.242e-03
# epoch  840   -   training loss: 1.238e-03   -   validation loss 1.232e-03
# epoch  850   -   training loss: 1.225e-03   -   validation loss 1.212e-03
# epoch  860   -   training loss: 1.215e-03   -   validation loss 1.198e-03
# epoch  870   -   training loss: 1.207e-03   -   validation loss 1.188e-03
# epoch  880   -   training loss: 1.200e-03   -   validation loss 1.156e-03
# epoch  890   -   training loss: 1.192e-03   -   validation loss 1.146e-03
# epoch  900   -   training loss: 1.183e-03   -   validation loss 1.107e-03
# epoch  910   -   training loss: 1.176e-03   -   validation loss 1.088e-03
# epoch  920   -   training loss: 1.164e-03   -   validation loss 1.087e-03
# epoch  930   -   training loss: 1.160e-03   -   validation loss 1.082e-03
# epoch  940   -   training loss: 1.154e-03   -   validation loss 1.077e-03
# epoch  950   -   training loss: 1.148e-03   -   validation loss 1.076e-03
# epoch  960   -   training loss: 1.139e-03   -   validation loss 1.052e-03
# epoch  970   -   training loss: 1.132e-03   -   validation loss 1.041e-03
# epoch  980   -   training loss: 1.127e-03   -   validation loss 1.019e-03
# epoch  990   -   training loss: 1.117e-03   -   validation loss 1.008e-03
# epoch 1000   -   training loss: 1.112e-03   -   validation loss 1.009e-03
# epoch 1010   -   training loss: 1.103e-03   -   validation loss 1.009e-03
# epoch 1020   -   training loss: 1.099e-03   -   validation loss 1.017e-03
# epoch 1030   -   training loss: 1.092e-03   -   validation loss 1.010e-03
# epoch 1040   -   training loss: 1.086e-03   -   validation loss 9.968e-04
# epoch 1050   -   training loss: 1.082e-03   -   validation loss 9.991e-04
# epoch 1060   -   training loss: 1.076e-03   -   validation loss 9.985e-04
# epoch 1070   -   training loss: 1.072e-03   -   validation loss 9.963e-04
# epoch 1080   -   training loss: 1.063e-03   -   validation loss 9.830e-04
# epoch 1090   -   training loss: 1.061e-03   -   validation loss 9.718e-04
# epoch 1100   -   training loss: 1.056e-03   -   validation loss 9.696e-04
# epoch 1110   -   training loss: 1.050e-03   -   validation loss 9.498e-04
# epoch 1120   -   training loss: 1.046e-03   -   validation loss 9.554e-04
# epoch 1130   -   training loss: 1.043e-03   -   validation loss 9.427e-04
# epoch 1140   -   training loss: 1.038e-03   -   validation loss 9.345e-04
# epoch 1150   -   training loss: 1.033e-03   -   validation loss 9.300e-04
# epoch 1160   -   training loss: 1.031e-03   -   validation loss 9.285e-04
# epoch 1170   -   training loss: 1.025e-03   -   validation loss 9.000e-04
# epoch 1180   -   training loss: 1.022e-03   -   validation loss 9.011e-04
# epoch 1190   -   training loss: 1.016e-03   -   validation loss 8.917e-04
# epoch 1200   -   training loss: 1.012e-03   -   validation loss 8.769e-04
# epoch 1210   -   training loss: 1.010e-03   -   validation loss 8.668e-04
# epoch 1220   -   training loss: 1.005e-03   -   validation loss 8.762e-04
# epoch 1230   -   training loss: 1.003e-03   -   validation loss 8.793e-04
# epoch 1240   -   training loss: 9.988e-04   -   validation loss 8.670e-04
# epoch 1250   -   training loss: 9.954e-04   -   validation loss 8.658e-04
# epoch 1260   -   training loss: 9.935e-04   -   validation loss 8.648e-04
# epoch 1270   -   training loss: 9.891e-04   -   validation loss 8.585e-04
# epoch 1280   -   training loss: 9.880e-04   -   validation loss 8.611e-04
# epoch 1290   -   training loss: 9.839e-04   -   validation loss 8.627e-04
# epoch 1300   -   training loss: 9.828e-04   -   validation loss 8.616e-04
# epoch 1310   -   training loss: 9.785e-04   -   validation loss 8.633e-04
# epoch 1320   -   training loss: 9.774e-04   -   validation loss 8.613e-04
# epoch 1330   -   training loss: 9.730e-04   -   validation loss 8.602e-04
# epoch 1340   -   training loss: 9.719e-04   -   validation loss 8.590e-04
# epoch 1350   -   training loss: 9.681e-04   -   validation loss 8.550e-04
# epoch 1360   -   training loss: 9.658e-04   -   validation loss 8.607e-04
# epoch 1370   -   training loss: 9.635e-04   -   validation loss 8.598e-04
# epoch 1380   -   training loss: 9.610e-04   -   validation loss 8.575e-04
# epoch 1390   -   training loss: 9.599e-04   -   validation loss 8.607e-04
# epoch 1400   -   training loss: 9.565e-04   -   validation loss 8.625e-04
# epoch 1410   -   training loss: 9.556e-04   -   validation loss 8.586e-04
# epoch 1420   -   training loss: 9.536e-04   -   validation loss 8.517e-04
# epoch 1430   -   training loss: 9.515e-04   -   validation loss 8.586e-04
# epoch 1440   -   training loss: 9.503e-04   -   validation loss 8.650e-04
# epoch 1450   -   training loss: 9.476e-04   -   validation loss 8.579e-04
# epoch 1460   -   training loss: 9.471e-04   -   validation loss 8.517e-04
# epoch 1470   -   training loss: 9.436e-04   -   validation loss 8.521e-04
# epoch 1480   -   training loss: 9.429e-04   -   validation loss 8.528e-04
# epoch 1490   -   training loss: 9.417e-04   -   validation loss 8.572e-04
# epoch 1500   -   training loss: 9.396e-04   -   validation loss 8.560e-04
# epoch 1510   -   training loss: 9.376e-04   -   validation loss 8.474e-04
# epoch 1520   -   training loss: 9.367e-04   -   validation loss 8.518e-04
# epoch 1530   -   training loss: 9.341e-04   -   validation loss 8.554e-04
# epoch 1540   -   training loss: 9.329e-04   -   validation loss 8.493e-04
# epoch 1550   -   training loss: 9.314e-04   -   validation loss 8.464e-04
# epoch 1560   -   training loss: 9.303e-04   -   validation loss 8.484e-04
# epoch 1570   -   training loss: 9.294e-04   -   validation loss 8.498e-04
# epoch 1580   -   training loss: 9.273e-04   -   validation loss 8.558e-04
# epoch 1590   -   training loss: 9.267e-04   -   validation loss 8.586e-04
# epoch 1600   -   training loss: 9.244e-04   -   validation loss 8.626e-04
# epoch 1610   -   training loss: 9.234e-04   -   validation loss 8.624e-04
# epoch 1620   -   training loss: 9.222e-04   -   validation loss 8.560e-04
# epoch 1630   -   training loss: 9.203e-04   -   validation loss 8.519e-04
# epoch 1640   -   training loss: 9.200e-04   -   validation loss 8.476e-04
# epoch 1650   -   training loss: 9.173e-04   -   validation loss 8.466e-04
# epoch 1660   -   training loss: 9.169e-04   -   validation loss 8.495e-04
# epoch 1670   -   training loss: 9.147e-04   -   validation loss 8.462e-04
# epoch 1680   -   training loss: 9.144e-04   -   validation loss 8.469e-04
# epoch 1690   -   training loss: 9.118e-04   -   validation loss 8.490e-04
# epoch 1700   -   training loss: 9.105e-04   -   validation loss 8.475e-04
# epoch 1710   -   training loss: 9.101e-04   -   validation loss 8.480e-04
# epoch 1720   -   training loss: 9.084e-04   -   validation loss 8.413e-04
# epoch 1730   -   training loss: 9.077e-04   -   validation loss 8.382e-04
# epoch 1740   -   training loss: 9.067e-04   -   validation loss 8.371e-04
# epoch 1750   -   training loss: 9.050e-04   -   validation loss 8.303e-04
# epoch 1760   -   training loss: 9.041e-04   -   validation loss 8.262e-04
# epoch 1770   -   training loss: 9.019e-04   -   validation loss 8.309e-04
# epoch 1780   -   training loss: 9.017e-04   -   validation loss 8.306e-04
# epoch 1790   -   training loss: 8.998e-04   -   validation loss 8.278e-04
# epoch 1800   -   training loss: 8.992e-04   -   validation loss 8.309e-04
# epoch 1810   -   training loss: 8.980e-04   -   validation loss 8.264e-04
# epoch 1820   -   training loss: 8.967e-04   -   validation loss 8.258e-04
# epoch 1830   -   training loss: 8.964e-04   -   validation loss 8.262e-04
# epoch 1840   -   training loss: 8.948e-04   -   validation loss 8.243e-04
# epoch 1850   -   training loss: 8.940e-04   -   validation loss 8.209e-04
# epoch 1860   -   training loss: 8.933e-04   -   validation loss 8.151e-04
# epoch 1870   -   training loss: 8.906e-04   -   validation loss 8.145e-04
# epoch 1880   -   training loss: 8.904e-04   -   validation loss 8.150e-04
# epoch 1890   -   training loss: 8.894e-04   -   validation loss 8.128e-04
# epoch 1900   -   training loss: 8.872e-04   -   validation loss 8.148e-04
# epoch 1910   -   training loss: 8.870e-04   -   validation loss 8.121e-04
# epoch 1920   -   training loss: 8.854e-04   -   validation loss 8.052e-04
# epoch 1930   -   training loss: 8.843e-04   -   validation loss 8.069e-04
# epoch 1940   -   training loss: 8.841e-04   -   validation loss 8.065e-04
# epoch 1950   -   training loss: 8.836e-04   -   validation loss 8.071e-04
# epoch 1960   -   training loss: 8.815e-04   -   validation loss 8.073e-04
# epoch 1970   -   training loss: 8.810e-04   -   validation loss 8.036e-04
# epoch 1980   -   training loss: 8.804e-04   -   validation loss 8.015e-04
# epoch 1990   -   training loss: 8.787e-04   -   validation loss 7.937e-04
# epoch 2000   -   training loss: 8.780e-04   -   validation loss 7.937e-04

# %% [markdown]
# We plot the progress of training and validation MSE during the advancement of epochs.

# %%
plt.loglog(opt.iterations_history, opt.loss_train_history, 'o-', label = 'training loss')
plt.loglog(opt.iterations_history, opt.loss_valid_history, 'o-', label = 'validation loss')
plt.axvline(num_epochs_Adam)
plt.xlabel('epochs'), plt.ylabel('MSE')
plt.legend()

# %% [markdown]
# ### Testing
#
# We predict the output field on the testing samples, and we compute error metrics: the normalized root mean square error and the Pearson dissimilarity.

# %%
# Compute predictions.
out_fields = LDNet(dataset_tests)

# Since the LDNet works with normalized data, we map back the outputs into the original ranges.
out_fields_app = utils.denormalize_output(out_fields, problem, normalization).numpy()
out_fields_ref = utils.denormalize_output(dataset_tests['out_fields'], problem, normalization).numpy()

NRMSE = np.sqrt(np.mean(np.square(out_fields_app - out_fields_ref))) / (np.max(out_fields_ref) - np.min(out_fields_ref))

import scipy.stats
R_coeff = scipy.stats.pearsonr(np.reshape(out_fields_app, (-1,)), np.reshape(out_fields_ref, (-1,)))

print('Normalized RMSE:       %1.3e' % NRMSE)
print('Pearson dissimilarity: %1.3e' % (1 - R_coeff[0]))
# Out:
# Normalized RMSE:       2.039e-02
# Pearson dissimilarity: 1.152e-02

# %% [markdown]
# Finally, we show a comparison between 24 samples from the test set and their correspondent LDNet approximation.

# %%
utils.plot_output_1D(dataset_tests, out_fields_ref, out_fields_app, 5, 4, title_ROM = 'LDNet')
